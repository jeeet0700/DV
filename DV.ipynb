# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
# 06_Probability_Distributions_1/
# 07_Pandas_1/
# 07_Probability_Distributions_2/
# DV.ipynb
# NPS.ipynb
# Numpy Airbnb NPS final .ipynb
# Pandas Revision.ipynb
# Pandas final cut.ipynb
# Pfizer_1.csv
# SQL/
# These Are the 25 Smartest Dog Breeds, According to Science.jpeg
# Think Stats, 2nd Edition_ Exploratory Data Analysis ( PDFDrive ).pdf
# Untitled.ipynb
# clouds-2627945.jpg
# directors.csv
# figure.png
# fit.txt
# gapminder.csv
# jupyterthemes.ipynb
# mckinsey.csv
# movies.csv
# prob_01_basic_definitions/
# storytelling-with-data-cole-nussbaumer-knaflic.pdf
# survey.txt

# %%
df=pd.read_csv("movies.csv")
df
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.loc[df["title"]=="Avatar"]
# Out:
#       id     budget  popularity     revenue   title  vote_average  vote_count  \
# 0  43597  237000000         150  2787965087  Avatar           7.2       11800
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday

# %%
df.index[df.loc[df["title"]=="Avatar"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/t2/3z1ygvv95h72q7ygpfjbdsgr0000gn/T/ipykernel_2351/1104993823.py in <module>
# ----> 1 df.index[df.loc[df["title"]=="Avatar"]]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     940             )
#     941         # fall back to Int64Index
# --> 942         return super().__getitem__(key)
#     943
#     944     def _getitem_slice(self: RangeIndex, slobj: slice) -> RangeIndex:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5067             key = np.asarray(key, dtype=bool)
#    5068
# -> 5069         result = getitem(key)
#    5070         # Because we ruled out integer above, we always get an arraylike here
#    5071         if result.ndim > 1:
#
# ...

# %%
df
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
mask=df["day"]=="Thursday"

# %%
mask
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: day, Length: 1465, dtype: bool

# %%
df[mask]
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 7     43608  200000000         107   586090727
# 11    43612  225000000          53   419651413
# 21    43626  200000000          93  1108561013
# 27    43634  200000000          46   491868548
# ...     ...        ...         ...         ...
# 1429  47949          0           2           0
# 1439  48146          0          10      316472
# 1443  48192     350000          35    29400000
# 1450  48267     400000          33   100000000
# 1452  48274          0           5     2611555
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 7                            Quantum of Solace           6.1        2965
# 11    The Chronicles of Narnia: Prince Caspian           6.3        1630
# 21                                     Skyfall           6.9        7604
# ...

# %%
x_val=[0,1,2]
y_val=[3,4,5]
plt.plot(x_val,y_val)
plt.show()

# %%
ls
# Out:
# 06_Probability_Distributions_1/
# 07_Pandas_1/
# 07_Probability_Distributions_2/
# DV.ipynb
# NPS.ipynb
# Numpy Airbnb NPS final .ipynb
# Pandas Revision.ipynb
# Pandas final cut.ipynb
# Pfizer_1.csv
# SQL/
# These Are the 25 Smartest Dog Breeds, According to Science.jpeg
# Think Stats, 2nd Edition_ Exploratory Data Analysis ( PDFDrive ).pdf
# Untitled.ipynb
# clouds-2627945.jpg
# directors.csv
# figure.png
# fit.txt
# gapminder.csv
# jupyterthemes.ipynb
# mckinsey.csv
# movies.csv
# prob_01_basic_definitions/
# storytelling-with-data-cole-nussbaumer-knaflic.pdf
# survey.txt

# %%
df
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df["day"].value_counts()
# Out:
# Friday       654
# Thursday     277
# Wednesday    276
# Tuesday       98
# Monday        67
# Saturday      47
# Sunday        46
# Name: day, dtype: int64

# %%
df_count=df["day"].value_counts()
df_count
# Out:
# Friday       654
# Thursday     277
# Wednesday    276
# Tuesday       98
# Monday        67
# Saturday      47
# Sunday        46
# Name: day, dtype: int64

# %%
df_count_index=df_count.index

# %%
plt.plot(df_count_index,df_count)

# %%
plt.bar(df_count_index,df_count)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(df_count,df_count_index)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(df_count_index,df_count)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.bar(df_count_index,df_count)
plt.xticks(rotation=45)
plt.show()

# %%
# !gdown 1upJyp4hzZVONmwiZvOfoKpA28uj2mJwo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1upJyp4hzZVONmwiZvOfoKpA28uj2mJwo
# To: /Users/jitendranathmahato/Downloads/Scaler/final_vg.csv
# 100%|██████████████████████████████████████| 2.04M/2.04M [00:00<00:00, 3.71MB/s]

# %%
ls
# Out:
# 06_Probability_Distributions_1/
# 07_Pandas_1/
# 07_Probability_Distributions_2/
# DV.ipynb
# NPS.ipynb
# Numpy Airbnb NPS final .ipynb
# Pandas Revision.ipynb
# Pandas final cut.ipynb
# Pfizer_1.csv
# SQL/
# These Are the 25 Smartest Dog Breeds, According to Science.jpeg
# Think Stats, 2nd Edition_ Exploratory Data Analysis ( PDFDrive ).pdf
# Untitled.ipynb
# clouds-2627945.jpg
# directors.csv
# figure.png
# final_vg.csv
# fit.txt
# gapminder.csv
# jupyterthemes.ipynb
# mckinsey.csv
# movies.csv
# prob_01_basic_definitions/
# storytelling-with-data-cole-nussbaumer-knaflic.pdf
# survey.txt

# %%
df=pd.read_csv("final_vg.csv")
df
# Out:
#         Rank                                           Name Platform    Year  \
# 0       2061                                           1942      NES  1985.0
# 1       9137                   ¡Shin Chan Flipa en colores!       DS  2007.0
# 2      14279              .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 3       8359                     .hack//G.U. Vol.1//Rebirth      PS2  2006.0
# 4       7109                   .hack//G.U. Vol.2//Reminisce      PS2  2006.0
# ...      ...                                            ...      ...     ...
# 16647   7925                             Zumba Fitness Rush     X360  2012.0
# 16648   6279                     Zumba Fitness: World Party      Wii  2013.0
# 16649   6977                     Zumba Fitness: World Party     XOne  2013.0
# 16650  15422                                         Zwei!!      PSP  2008.0
# 16651  12919  Zyuden Sentai Kyoryuger: Game de Gaburincho!!      3DS  2013.0
#
# ...

# %%
gen_count=df["Genre"].value_counts()
gen_count
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
gen_count_index=gen_count.index
gen_count_index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='object')

# %%
plt.plot(gen_count_index,gen_count)
plt.show()

# %%
plt.plot(gen_count_index,gen_count)
plt.xticks(rotation=45)
plt.show()

# %%
x=gen_count_index
y=gen_count

# %%
plt.plot(x,y)
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(x,y)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.bar(x,y)
plt.show()
